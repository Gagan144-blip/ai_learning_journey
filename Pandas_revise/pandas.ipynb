# %%
import numpy as np

# %%
import pandas as pd

# %%
ser = pd.Series()
ser
# Out:
# Series([], dtype: object)

# %%
data = np.array(['g','e','e','k', 's'])

ser = pd.Series(data)
print(ser)
# Out:
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: str

# %%
# from a list
data = ['g', 'e', 'e', 'k', 's']
ser = pd.Series(data)
print(ser)
# Out:
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: str

# %%
# using numpy function

ser = pd.Series(np.linspace(1, 10, 5))
ser
# Out:
# 0     1.00
# 1     3.25
# 2     5.50
# 3     7.75
# 4    10.00
# dtype: float64

# %%
#using arange function
ser = pd.Series(np.arange(6, 20, 2))
ser
# Out:
# 0     6
# 1     8
# 2    10
# 3    12
# 4    14
# 5    16
# 6    18
# dtype: int64

# %%
# Pandas DataFrame
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lst = ['series', 'dataframe', 'panel']
df = pd.DataFrame(lst)
print(df)
# Out:
#            0
# 0     series
# 1  dataframe
# 2      panel

# %%
data = {
    'a': np.array([2, 3, 4]),
    'b': np.array([4, 5, 4]),
    'c': np.array([3,4 ,5])
}
df = pd.DataFrame(data)
print(df)
# Out:
#    a  b  c
# 0  2  4  3
# 1  3  5  4
# 2  4  4  5

# %%
# setting a custom index 
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}

df = pd.DataFrame(data)
res = df.set_index('Age')
print(res)
# Out:
#         Name         City
# Age
# 25     Alice     New York
# 30       Bob  Los Angeles
# 35   Charlie      Chicago

# %%
# to reset index to default
res = df.reset_index(drop=True)
print(res)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
# indexing with loc
df = pd.DataFrame(data, index=['A', 'B', 'C'])
print(df)
print(df.loc['A'])
# Out:
#       Name  Age         City
# A    Alice   25     New York
# B      Bob   30  Los Angeles
# C  Charlie   35      Chicago
# Name       Alice
# Age           25
# City    New York
# Name: A, dtype: object

# %%
# accessing row by index
# iloc -> for positional indexing
# loc -> for label based indexing
second_row = df.iloc[0]
print(second_row)
# Out:
# Name       Alice
# Age           25
# City    New York
# Name: A, dtype: object

# %%
# access multiple rows
multiple_rows = df.loc['A':'C', ['Name', 'Age']]
print(multiple_rows)
# Out:
#       Name  Age
# A    Alice   25
# B      Bob   30
# C  Charlie   35

# %%
# access value at specific cell using at and iat
age_at_index = df.at['A', 'Age']
print(age_at_index)
# Out:
# 25

# %%
# iat
Name_at_index = df.iat[2, 1]
print(Name_at_index)
# Out:
# 35

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\kgaga\\Desktop\\AI_LEARNING_JOURNEY\\Crop_recommendation (1).csv')

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
# retrieve single column
first = df['K']
print(first)
# Out:
# 0       43
# 1       41
# 2       44
# 3       40
# 4       42
#         ..
# 2195    32
# 2196    27
# 2197    30
# 2198    34
# 2199    30
# Name: K, Length: 2200, dtype: int64

# %%
ft = df[['N','P', 'K']]
print(ft)
# Out:
#         N   P   K
# 0      90  42  43
# 1      85  58  41
# 2      60  55  44
# 3      74  35  40
# 4      78  42  42
# ...   ...  ..  ..
# 2195  107  34  32
# 2196   99  15  27
# 2197  118  33  30
# 2198  117  32  34
# 2199  104  18  30
#
# [2200 rows x 3 columns]

# %%
# retrieve single row
row = df.loc[4]
row
# Out:
# N                     78
# P                     42
# K                     42
# temperature    20.130175
# humidity       81.604873
# ph              7.628473
# rainfall       262.71734
# label               rice
# Name: 4, dtype: object

# %%
# select specific rows and columns by position
st = df.iloc[[3, 44, 5], [5, 4]]
print(st)
# Out:
#           ph   humidity
# 3   6.980401  80.158363
# 44  7.224286  82.366990
# 5   7.073454  83.370118

# %%
# select all rows and spefici columns
# iloc needs numeric values for indexing
s1 = df.iloc[:, [0, 4, 5]]
print(s1)
# Out:
#         N   humidity        ph
# 0      90  82.002744  6.502985
# 1      85  80.319644  7.038096
# 2      60  82.320763  7.840207
# 3      74  80.158363  6.980401
# 4      78  81.604873  7.628473
# ...   ...        ...       ...
# 2195  107  66.413269  6.780064
# 2196   99  56.636362  6.086922
# 2197  118  67.225123  6.362608
# 2198  117  52.127394  6.758793
# 2199  104  60.396475  6.779833
#
# [2200 rows x 3 columns]

# %%
dy = df[df['N'] > 75]
print(dy)
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# 7      94  53  40    20.277744  82.894086  5.718627  241.974195    rice
# 8      89  54  38    24.515881  83.535216  6.685346  230.446236    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [675 rows x 8 columns]

# %%
custom = df.iloc[8:732]
print(custom)
# Out:
#      P   K  temperature   humidity        ph    rainfall      label
# N
# 89  54  38    24.515881  83.535216  6.685346  230.446236       rice
# 68  58  38    23.223974  83.033227  6.336254  221.209196       rice
# 91  53  40    26.527235  81.417538  5.386168  264.614870       rice
# 90  46  42    23.978982  81.450616  7.502834  250.083234       rice
# 78  58  44    26.800796  80.886848  5.108682  284.436457       rice
# ..  ..  ..          ...        ...       ...         ...        ...
# 48  62  15    25.365861  66.637972  7.538631   65.816559  blackgram
# 32  66  17    34.946616  65.267740  7.162358   70.141514  blackgram
# 21  63  22    25.097374  67.728379  6.859409   74.616499  blackgram
# 20  72  19    32.476483  64.348487  7.397191   65.820457  blackgram
# 25  65  21    33.863512  68.592323  6.880246   69.244641  blackgram
#
# [724 rows x 7 columns]

# %%
df = pd.read_csv('C:\\Users\\kgaga\\Desktop\\AI_LEARNING_JOURNEY\\Titanic-Dataset.csv')

# %%
data = pd.DataFrame(df)
display(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
display(data.loc[
    (data['Age'] > 30) &
    (data['Fare'] > 70) &
    (data['PassengerId'] < 5) &
    (data['Name'].str.startswith('C')),
    ['Name', 'Ticket']
])
# Out:
#                                                 Name    Ticket
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  PC 17599

# %%
filtered_values = np.where(
    (data['Age'] > 30) &
    (data['Fare'] > 70) &
    (data['PassengerId'] < 5) &
    (data['Name'].str.startswith('C'))
)

print(filtered_values)

display(data.iloc[filtered_values])
# Out:
# (array([1]),)
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C

# %% [markdown]
# Pandas Merging, joining and Concatenating

# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd

data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd'],
         'Mobile No': [97, 91, 58, 76]}

data2 = {'Name': ['Gaurav', 'Anuj', 'Dhiraj', 'Hitesh'],
         'Age': [22, 32, 12, 52],
         'Address': ['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'],
         'Qualification': ['MCA', 'Phd', 'Bcom', 'B.hons'],
         'Salary': [1000, 2000, 3000, 4000]}

df = pd.DataFrame(data1, index=[0, 1, 2, 3])

df1 = pd.DataFrame(data2, index=[2, 3, 6, 7])

print(df, "\n\n", df1)
# Out:
#      Name  Age    Address Qualification  Mobile No
# 0     Jai   27     Nagpur           Msc         97
# 1  Princi   24     Kanpur            MA         91
# 2  Gaurav   22  Allahabad           MCA         58
# 3    Anuj   32    Kannuaj           Phd         76
#
#       Name  Age    Address Qualification  Salary
# 2  Gaurav   22  Allahabad           MCA    1000
# 3    Anuj   32    Kannuaj           Phd    2000
# 6  Dhiraj   12  Allahabad          Bcom    3000
# 7  Hitesh   52    Kannuaj        B.hons    4000

# %%
frames = [df, df1]
res1 = pd.concat(frames)
res1
# Out:
#      Name  Age    Address Qualification  Mobile No  Salary
# 0     Jai   27     Nagpur           Msc       97.0     NaN
# 1  Princi   24     Kanpur            MA       91.0     NaN
# 2  Gaurav   22  Allahabad           MCA       58.0     NaN
# 3    Anuj   32    Kannuaj           Phd       76.0     NaN
# 2  Gaurav   22  Allahabad           MCA        NaN  1000.0
# 3    Anuj   32    Kannuaj           Phd        NaN  2000.0
# 6  Dhiraj   12  Allahabad          Bcom        NaN  3000.0
# 7  Hitesh   52    Kannuaj        B.hons        NaN  4000.0

# %% [markdown]
# .concat using logic on axes
# axes join = inner -> keeps only the common columns
# axes join = outer -> gives union of all the dataFrames

# %%
res2 = pd.concat([df, df1], axis=1, join='inner')
res2
# Out:
#      Name  Age    Address Qualification  Mobile No    Name  Age    Address  \
# 2  Gaurav   22  Allahabad           MCA         58  Gaurav   22  Allahabad
# 3    Anuj   32    Kannuaj           Phd         76    Anuj   32    Kannuaj
#
#   Qualification  Salary
# 2           MCA    1000
# 3           Phd    2000

# %%
res3 = pd.concat([df, df1], axis=1, join='outer')
res3
# Out:
#      Name   Age    Address Qualification  Mobile No    Name   Age    Address  \
# 0     Jai  27.0     Nagpur           Msc       97.0     NaN   NaN        NaN
# 1  Princi  24.0     Kanpur            MA       91.0     NaN   NaN        NaN
# 2  Gaurav  22.0  Allahabad           MCA       58.0  Gaurav  22.0  Allahabad
# 3    Anuj  32.0    Kannuaj           Phd       76.0    Anuj  32.0    Kannuaj
# 6     NaN   NaN        NaN           NaN        NaN  Dhiraj  12.0  Allahabad
# 7     NaN   NaN        NaN           NaN        NaN  Hitesh  52.0    Kannuaj
#
#   Qualification  Salary
# 0           NaN     NaN
# 1           NaN     NaN
# 2           MCA  1000.0
# 3           Phd  2000.0
# 6          Bcom  3000.0
# 7        B.hons  4000.0
